# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # 1. SQL Programming - Text, Time and Date Strings

# %% [markdown]
# ## 1.0 Connecting to our Database

# %%
# We will first load the sql extension into our environment
# %load_ext sql

# Then connect to our in memory sqlite database
# NB: This database will cease to exist as soon as the database connection is closed. 
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# Datasets used in this notebook:
#
#
# 1.   **Main Lighting Energy Sources averaged to Districts in 2009**
#
# > ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1XyZwH35bo99OZIAGHH8LMN48stLwyG-b/view?usp=sharing))
#
# 2.   **Kisumu County Energy and Mining Project Implementation Status**
#
# > ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1awhsX-tmd_RvM1PxPhhg21GTFuDn34ca/view?usp=sharing))
#
# 3. **Population by District**
#
# >  ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1ZpbtJ-YAzfAtnQ4k-R_zpEbYRvP5lZhr/view?usp=sharing))
#
# 4. **Visitors to Kenya between 1991 to 2014**
#
# >  ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1FJs1YU76tRyHEtHU6w62LYQlR8Jz_4d1/view?usp=sharing))
#
# 5. **Boston Marathon Results 2016**
#
# >  ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/1FKhXZemUZuwYSJydUDgukyqJt3ouvKGi/view?usp=sharing))
#
# 6. **Kenyan Government Appointments**
#
# >  ([Dataset Download Link](https://drive.google.com/a/moringaschool.com/file/d/19m7bydCYOyH8qb68S-Jn-dAX0TrjSHKh/view?usp=sharing))
#
# 7. **Tea Production**
#
# >  ([Dataset Download Link](https://drive.google.com/open?id=1Nf3SfkLuxK8oWX2m_RAOILLrpY7pFDaF))

# %% [markdown]
# ## 1.1 Loading our Datasets

# %%
# Importing Pandas
import pandas as pd

# %%
# Loading our lighting dataset  from the respective CSV file 
with open('lighting_dataset.csv','r') as f:
    LightingDataset = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS LightingDataset;
# %sql PERSIST LightingDataset;
# %sql SELECT * FROM LightingDataset LIMIT 5;
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9e925a2f7fdc> in <module>()
#       1 # Loading our lighting dataset  from the respective CSV file
# ----> 2 with open('lighting_dataset.csv','r') as f:
#       3     LightingDataset = pd.read_csv(f, index_col=0, encoding='utf-8')
#       4 get_ipython().magic('sql DROP TABLE if EXISTS LightingDataset;')
#       5 get_ipython().magic('sql PERSIST LightingDataset;')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lighting_dataset.csv'

# %%
# Loading our energy mining dataset from the respective CSV file 

with open('energy_mining_dataset.csv','r') as f:
    EnergyDataset = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS EnergyDataset;
# %sql PERSIST EnergyDataset;
# %sql SELECT * FROM EnergyDataset LIMIT 5;

# %%
# Loading our population by districtdataset from the respective CSV file

with open('population_by_district.csv','r') as f:
    PopulationDistrict = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS PopulationDistrict;
# %sql PERSIST PopulationDistrict;
# %sql SELECT * FROM PopulationDistrict LIMIT 5;

# %%
# Loading our visitors to kenya dataset from the respective CSV file

with open('visitors_to_kenya.csv','r') as f:
    VisitorsKenya = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS VisitorsKenya;
# %sql PERSIST VisitorsKenya;
# %sql SELECT * FROM VisitorsKenya LIMIT 5;

# %%
# Loading our marathon dataset from the respective CSV file
#

with open('marathon_results_2016.csv','r') as f:
    MarathonResults = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS MarathonResults;
# %sql PERSIST MarathonResults;
# %sql SELECT * FROM MarathonResults LIMIT 5;
# Out:
#  * sqlite://
# Done.
#  * sqlite://
#  * sqlite://
# Done.
# [('5', 'Hayle, Lemi Berhanu', 21, 'M', 'Addis Ababa', None, 'ETH', None, None, '00:15:47', '00:31:20', '00:47:07', '01:03:14', '01:06:45', '01:19:15', '01:34:17', '01:50:24', '02:05:59', '00:05:04', '02:12:45', '02:12:45', 1, 1, 1),
#  ('1', 'Desisa, Lelisa', 26, 'M', 'Ambo', None, 'ETH', None, None, '00:15:47', '00:31:21', '00:47:08', '01:03:14', '01:06:46', '01:19:15', '01:34:17', '01:50:24', '02:05:59', '00:05:06', '02:13:32', '02:13:32', 2, 2, 2),
#  ('6', 'Tsegay, Yemane Adhane', 31, 'M', 'Addis Ababa', None, 'ETH', None, None, '00:15:46', '00:31:20', '00:47:07', '01:03:13', '01:06:44', '01:19:15', '01:34:45', '01:50:48', '02:06:47', '00:05:07', '02:14:02', '02:14:02', 3, 3, 3),
#  ('11', 'Korir, Wesley', 33, 'M', 'Kitale', None, 'KEN', None, None, '00:15:46', '00:31:21', '00:47:07', '01:03:14', '01:06:46', '01:19:16', '01:34:45', '01:50:48', '02:06:47', '00:05:07', '02:14:05', '02:14:05', 4, 4, 4),
#  ('14', 'Lonyangata, Paul', 23, 'M', 'Eldoret', None, 'KEN', None, None, '00:15:46', '00:31:21', '00:47:08', '01:03:14', '01:06:46', '01:19:18', '01:34:46', '01:51:30', '02:08:11', '00:05:11', '02:15:45', '02:15:45', 5, 5, 5)]

# %%
# Loading our Kenyan government appointments dataset below
#

with open('government_appointments.csv','r') as f:
    GovernmentAppointments = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS GovernmentAppointments;
# %sql PERSIST GovernmentAppointments;
# %sql SELECT * FROM GovernmentAppointments LIMIT 5;

# %%
# Loading our Tea dataset below
#

with open('tea_production.csv','r') as f:
    TeaProduction = pd.read_csv(f, index_col=0, encoding='utf-8')
# %sql DROP TABLE if EXISTS TeaProduction;
# %sql PERSIST TeaProduction;
# %sql SELECT * FROM TeaProduction LIMIT 5;

# %% [markdown]
# ## 1.2 Text Strings

# %%
# Example 1
# Using the EnergyMining dataset, we can concatenate (combine) 
# the Ward and County columns (i.e attributes)
# into a new column Region. Then only select 5 of those regions
#
# %%sql  
SELECT *, WARD || ', ' || COUNTY AS Region
FROM EnergyDataset LIMIT 5;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: EnergyDataset
# [SQL: SELECT *, WARD || ', ' || COUNTY AS Region
# FROM EnergyDataset LIMIT 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Example 2
# Using the main energy dataset, we can also replace the null cells with 0
# as shown below
# 
# %%sql 
SELECT PROJECT_NAME, REPLACE("STATUS", '100 % Complete', '100%') AS "Project Status" 
FROM EnergyDataset;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: EnergyDataset
# [SQL: SELECT PROJECT_NAME, REPLACE("STATUS", '100 % Complete', '100%') AS "Project Status"
# FROM EnergyDataset;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Example 3
# Using the Population by District dataset, we change values of County column to lowercase 
# as shown below
#
# %%sql
SELECT *, LOWER(County) AS "County Name"
FROM PopulationDistrict limit 5;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: PopulationDistrict
# [SQL: SELECT *, LOWER(County) AS "County Name"
# FROM PopulationDistrict limit 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ### <font color="green">1.2 Challenges</font>

# %%
# Challenge 1
# Using the Governments appointments dataset, 
# in gender field, let's replace m = 1 and f = 0
# 

# %%sql
Select * , replace (replace("Gender", 'm', '1') , 'f', '0')as "Gender1"
from GovernmentAppointments limit 5;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: GovernmentAppointments
# [SQL: Select * , replace (replace("Gender", 'm', '1') , 'f', '0')as "Gender1"
# from GovernmentAppointments limit 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Challenge 2
# Using the Governments appointments dataset, 
# Let's merge the person appointing field with the appointers position field
#

# %%sql
Select *, Person_Appointing_ ||','|| Apointers_Position as Employer
from GovernmentAppointments limit 5;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: GovernmentAppointments
# [SQL: Select *, Person_Appointing_ ||','|| Apointers_Position as Employer
# from GovernmentAppointments limit 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Challenge 3
# Using the Population by District dataset, 
# let's change the values of the District column to lowercase 
# and display these values in a new column 
# 

# %%sql
Select * , LOWER (District) as 'District Name'
from PopulationDistrict limit 5;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: PopulationDistrict
# [SQL: Select * , LOWER (District) as 'District Name'
# from PopulationDistrict limit 5;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## 1.3 Time Strings

# %%
# Example 1
# You can work with time data just like any other kind of data type 
# when it is in the time format; HH:MM:SS
# Let's answer some questions to see how this works
# Question: Which athletes took time between 15.30 and 15.59 to pass the 5K mark?
# NB: We order the results
#
# %%sql 
SELECT Name, "5K" FROM MarathonResults 
WHERE "5K" > '0:15:30' and "5K" < '0:15:59' ORDER BY "5K" ASC;
# Out:
#  * sqlite://
# Done.
# [('Tsegay, Yemane Adhane', '0:15:46'),
#  ('Korir, Wesley', '0:15:46'),
#  ('Lonyangata, Paul', '0:15:46'),
#  ('Kitwara, Sammy', '0:15:46'),
#  ('Feleke, Getu', '0:15:46'),
#  ('Mekonnen, Tsegaye', '0:15:46'),
#  ('Kiprop, Jackson', '0:15:46'),
#  ('Da Silva, Solonei', '0:15:46'),
#  ('Hayle, Lemi Berhanu', '0:15:47'),
#  ('Desisa, Lelisa', '0:15:47'),
#  ('Chebogut, Stephen', '0:15:47'),
#  ('Nageeye, Abdi', '0:15:47'),
#  ('Nyasango, Cutbert', '0:15:47'),
#  ('Kamijo, Norio', '0:15:47'),
#  ('Kipyego, Michael', '0:15:47'),
#  ('Sanabria, Alvaro', '0:15:51'),
#  ('Okuti, Harbert', '0:15:53'),
#  ('Burrell, Ian', '0:15:54'),
#  ('Simpson, Jason M.', '0:15:54')]

# %%
# Example 2
# Finding the minimum amount of time taken to cover 15K by an athlete during the marathon. 
# Hint: We use a where clause to ignore null/blank values - we will learn how to 
# deal with such values later in the course
# 
# %%sql
SELECT Name, MIN("5K") 
FROM MarathonResults 
WHERE "5K" > 0;
# Out:
#  * sqlite://
# Done.
# [('Tsegay, Yemane Adhane', '0:15:46')]

# %%
# Example 3
# What was the average time covered by all athletes past the 10K mark?
# 
# %%sql
SELECT time(AVG("10K")) 
FROM MarathonResults 
WHERE "10K" > 0;
# Out:
#  * sqlite://
# Done.
# [('15:06:58',)]

# %% [markdown]
# ### <font color="green">1.3 Challenges</font>

# %%
# Challenge 1
# What were the names and time of the athletes who finished the marathon before 2hrs 15min official time?
# NB: Order your names by time in ascending order
# 

# %%sql
Select Name, "Official Time" from MarathonResults
Where "Official Time" < '02:15:00' and "Official Time" > 0
Order by "Official Time" ASC;
# Out:
#  * sqlite://
# Done.
# []

# %%
# %%sql
# select "Official Time" from MarathonResults;
# Out:
#  * sqlite://
# Done.
# [('2:12:45',),
#  ('2:13:32',),
#  ('2:14:02',),
#  ('2:14:05',),
#  ('2:15:45',),
#  ('2:16:43',),
#  ('2:16:52',),
#  ('2:18:05',),
#  ('2:18:46',),
#  ('2:21:37',),
#  ('2:22:02',),
#  ('2:22:21',),
#  ('2:22:22',),
#  ('2:24:44',),
#  ('2:24:46',),
#  ('2:24:54',),
#  ('2:24:55',),
#  ('2:25:31',),
#  ('2:26:24',),
#  ('2:27:02',),
#  ('2:27:07',),
#  ('2:27:41',),
#  ('2:27:48',),
#  ('2:27:53',),
#  ('2:28:14',),
#  ('2:28:26',),
#  ('2:28:53',),
#  ('2:29:09',),
#  ('2:29:19',),
#  ('2:29:23',),
#  ('2:29:32',),
#  ('2:29:51',),
#  ('2:30:03',),
#  ('2:30:22',),
#  ('2:30:27',),
#  ('2:30:50',),
#  ('2:30:57',),
#  ('2:31:14',),
#  ('2:31:16',),
#  ('2:31:24',),
#  ('2:31:39',),
#  ('2:31:47',),
#  ('2:32:00',),
#  ('2:32:28',),
#  ('2:32:37',),
#  ('2:32:44',),
#  ('2:32:45',),
#  ('2:33:03',),
#  ('2:33:13',),
#  ('2:33:19',),
#  ('2:33:23',),
#  ('2:33:35',),
#  ('2:33:40',),
#  ('2:33:46',),
#  ('2:33:50',),
#  ('2:33:56',),
#  ('2:34:02',),
#  ('2:34:12',),
#  ('2:34:15',),
#  ('2:34:17',),
#  ('2:34:19',),
#  ('2:34:20',),
#  ('2:34:30',),
#  ('2:34:35',),
#  ('2:34:38',),
#  ('2:34:41',),
#  ('2:34:43',),
#  ('2:34:55',),
#  ('2:35:00',),
#  ('2:35:00',),
#  ('2:35:16',),
#  ('2:35:24',),
#  ('2:35:40',),
#  ('2:35:48',),
#  ('2:35:50',),
#  ('2:36:02',),
#  ('2:36:04',),
#  ('2:36:08',),
#  ('2:36:10',),
#  ('2:36:11',),
#  ('2:36:12',),
#  ('2:36:18',),
#  ('2:36:21',),
#  ('2:36:31',),
#  ('2:36:54',),
#  ('2:36:58',),
#  ('2:37:01',),
#  ('2:37:10',),
#  ('2:37:11',),
#  ('2:37:23',),
#  ('2:37:23',),
#  ('2:37:26',),
#  ('2:37:30',),
#  ('2:37:31',),
#  ('2:37:33',),
#  ('2:37:35',),
#  ('2:37:36',),
#  ('2:37:36',),
#  ('2:37:36',),
#  ('2:37:46',),
#  ('2:37:50',),
#  ('2:37:56',),
#  ('2:37:56',),
#  ('2:38:02',),
#  ('2:38:16',),
#  ('2:38:17',),
#  ('2:38:18',),
#  ('2:38:22',),
#  ('2:38:23',),
#  ('2:38:23',),
#  ('2:38:27',),
#  ('2:38:30',),
#  ('2:38:30',),
#  ('2:38:45',),
#  ('2:38:51',),
#  ('2:38:51',),
#  ('2:39:00',),
#  ('2:39:04',),
#  ('2:39:04',),
#  ('2:39:14',),
#  ('2:39:14',),
#  ('2:39:19',),
#  ('2:39:21',),
#  ('2:39:28',),
#  ('2:39:33',),
#  ('2:39:38',),
#  ('2:39:41',),
#  ('2:39:42',),
#  ('2:39:44',),
#  ('2:39:47',),
#  ('2:39:48',),
#  ('2:39:52',),
#  ('2:39:52',),
#  ('2:39:55',),
#  ('2:39:55',),
#  ('2:40:02',),
#  ('2:40:19',),
#  ('2:40:19',),
#  ('2:40:31',),
#  ('2:40:34',),
#  ('2:40:41',),
#  ('2:40:47',),
#  ('2:40:50',),
#  ('2:40:52',),
#  ('2:40:54',),
#  ('2:40:54',),
#  ('2:41:00',),
#  ('2:41:00',),
#  ('2:41:02',),
#  ('2:41:06',),
#  ('2:41:07',),
#  ('2:41:08',),
#  ('2:41:08',),
#  ('2:41:09',),
#  ('2:41:16',),
#  ('2:41:17',),
#  ('2:41:28',),
#  ('2:41:32',),
#  ('2:41:40',),
#  ('2:41:41',),
#  ('2:41:44',),
#  ('2:41:51',),
#  ('2:41:54',),
#  ('2:42:00',),
#  ('2:42:00',),
#  ('2:42:00',),
#  ('2:42:01',),
#  ('2:42:02',),
#  ('2:42:03',),
#  ('2:42:07',),
#  ('2:42:08',),
#  ('2:42:10',),
#  ('2:42:13',),
#  ('2:42:17',),
#  ('2:42:17',),
#  ('2:42:18',),
#  ('2:42:20',),
#  ('2:42:23',),
#  ('2:42:24',),
#  ('2:42:25',),
#  ('2:42:27',),
#  ('2:42:28',),
#  ('2:42:29',),
#  ('2:42:31',),
#  ('2:42:33',),
#  ('2:42:34',),
#  ('2:42:35',),
#  ('2:42:38',),
#  ('2:42:38',),
#  ('2:42:40',),
#  ('2:42:46',),
#  ('2:42:46',),
#  ('2:42:46',),
#  ('2:42:48',),
#  ('2:42:50',),
#  ('2:42:55',),
#  ('2:42:57',),
#  ('2:43:01',),
#  ('2:43:02',),
#  ('2:43:06',),
#  ('2:43:08',),
#  ('2:43:09',),
#  ('2:43:11',),
#  ('2:43:13',),
#  ('2:43:13',),
#  ('2:43:14',),
#  ('2:43:15',),
#  ('2:43:17',),
#  ('2:43:19',),
#  ('2:43:19',),
#  ('2:43:21',),
#  ('2:43:22',),
#  ('2:43:26',),
#  ('2:43:30',),
#  ('2:43:33',),
#  ('2:43:33',),
#  ('2:43:34',),
#  ('2:43:35',),
#  ('2:43:35',),
#  ('2:43:37',),
#  ('2:43:38',),
#  ('2:43:40',),
#  ('2:43:45',),
#  ('2:43:49',),
#  ('2:43:51',),
#  ('2:43:53',),
#  ('2:43:55',),
#  ('2:43:55',),
#  ('2:43:55',),
#  ('2:43:55',),
#  ('2:43:56',),
#  ('2:44:00',),
#  ('2:44:00',),
#  ('2:44:02',),
#  ('2:44:02',),
#  ('2:44:07',),
#  ('2:44:07',),
#  ('2:44:08',),
#  ('2:44:09',),
#  ('2:44:11',),
#  ('2:44:16',),
#  ('2:44:17',),
#  ('2:44:17',),
#  ('2:44:18',),
#  ('2:44:18',),
#  ('2:44:20',),
#  ('2:44:20',),
#  ('2:44:28',),
#  ('2:44:32',),
#  ('2:44:32',),
#  ('2:44:33',),
#  ('2:44:33',),
#  ('2:44:34',),
#  ('2:44:35',),
#  ('2:44:35',),
#  ('2:44:38',),
#  ('2:44:47',),
#  ('2:44:48',),
#  ('2:44:59',),
#  ('2:45:01',),
#  ('2:45:03',),
#  ('2:45:09',),
#  ('2:45:12',),
#  ('2:45:12',),
#  ('2:45:13',),
#  ('2:45:14',),
#  ('2:45:15',),
#  ('2:45:16',),
#  ('2:45:16',),
#  ('2:45:17',),
#  ('2:45:18',),
#  ('2:45:19',),
#  ('2:45:20',),
#  ('2:45:22',),
#  ('2:45:22',),
#  ('2:45:23',),
#  ('2:45:24',),
#  ('2:45:24',),
#  ('2:45:27',),
#  ('2:45:28',),
#  ('2:45:28',),
#  ('2:45:29',),
#  ('2:45:29',),
#  ('2:45:31',),
#  ('2:45:35',),
#  ('2:45:47',),
#  ('2:45:47',),
#  ('2:45:51',),
#  ('2:45:53',),
#  ('2:45:55',),
#  ('2:45:55',),
#  ('2:45:55',),
#  ('2:45:56',),
#  ('2:45:57',),
#  ('2:45:58',),
#  ('2:45:59',),
#  ('2:46:00',),
#  ('2:46:01',),
#  ('2:46:03',),
#  ('2:46:06',),
#  ('2:46:07',),
#  ('2:46:08',),
#  ('2:46:10',),
#  ('2:46:12',),
#  ('2:46:14',),
#  ('2:46:14',),
#  ('2:46:18',),
#  ('2:46:20',),
#  ('2:46:22',),
#  ('2:46:29',),
#  ('2:46:30',),
#  ('2:46:30',),
#  ('2:46:32',),
#  ('2:46:32',),
#  ('2:46:32',),
#  ('2:46:34',),
#  ('2:46:37',),
#  ('2:46:38',),
#  ('2:46:41',),
#  ('2:46:42',),
#  ('2:46:42',),
#  ('2:46:46',),
#  ('2:46:47',),
#  ('2:46:48',),
#  ('2:46:54',),
#  ('2:46:57',),
#  ('2:46:57',),
#  ('2:46:58',),
#  ('2:46:58',),
#  ('2:46:59',),
#  ('2:46:59',),
#  ('2:47:01',),
#  ('2:47:02',),
#  ('2:47:03',),
#  ('2:47:04',),
#  ('2:47:06',),
#  ('2:47:07',),
#  ('2:47:07',),
#  ('2:47:09',),
#  ('2:47:11',),
#  ('2:47:12',),
#  ('2:47:13',),
#  ('2:47:15',),
#  ('2:47:16',),
#  ('2:47:19',),
#  ('2:47:20',),
#  ('2:47:20',),
#  ('2:47:23',),
#  ('2:47:25',),
#  ('2:47:25',),
#  ('2:47:25',),
#  ('2:47:27',),
#  ('2:47:27',),
#  ('2:47:27',),
#  ('2:47:29',),
#  ('2:47:30',),
#  ('2:47:32',),
#  ('2:47:32',),
#  ('2:47:35',),
#  ('2:47:39',),
#  ('2:47:39',),
#  ('2:47:40',),
#  ('2:47:40',),
#  ('2:47:40',),
#  ('2:47:41',),
#  ('2:47:43',),
#  ('2:47:45',),
#  ('2:47:47',),
#  ('2:47:49',),
#  ('2:47:50',),
#  ('2:47:50',),
#  ('2:47:50',),
#  ('2:47:52',),
#  ('2:47:52',),
#  ('2:47:57',),
#  ('2:47:58',),
#  ('2:48:01',),
#  ('2:48:03',),
#  ('2:48:03',),
#  ('2:48:08',),
#  ('2:48:09',),
#  ('2:48:10',),
#  ('2:48:13',),
#  ('2:48:14',),
#  ('2:48:16',),
#  ('2:48:17',),
#  ('2:48:18',),
#  ('2:48:19',),
#  ('2:48:22',),
#  ('2:48:23',),
#  ('2:48:23',),
#  ('2:48:25',),
#  ('2:48:26',),
#  ('2:48:26',),
#  ('2:48:31',),
#  ('2:48:35',),
#  ('2:48:36',),
#  ('2:48:39',),
#  ('2:48:39',),
#  ('2:48:40',),
#  ('2:48:40',),
#  ('2:48:42',),
#  ('2:48:42',),
#  ('2:48:43',),
#  ('2:48:43',),
#  ('2:48:44',),
#  ('2:48:44',),
#  ('2:48:47',),
#  ('2:48:47',),
#  ('2:48:47',),
#  ('2:48:48',),
#  ('2:48:48',),
#  ('2:48:49',),
#  ('2:48:50',),
#  ('2:48:50',),
#  ('2:48:53',),
#  ('2:48:53',),
#  ('2:48:54',),
#  ('2:48:57',),
#  ('2:48:57',),
#  ('2:48:57',),
#  ('2:48:58',),
#  ('2:48:59',),
#  ('2:48:59',),
#  ('2:49:00',),
#  ('2:49:01',),
#  ('2:49:02',),
#  ('2:49:03',),
#  ('2:49:04',),
#  ('2:49:05',),
#  ('2:49:06',),
#  ('2:49:07',),
#  ('2:49:07',),
#  ('2:49:09',),
#  ('2:49:09',),
#  ('2:49:12',),
#  ('2:49:14',),
#  ('2:49:14',),
#  ('2:49:16',),
#  ('2:49:17',),
#  ('2:49:18',),
#  ('2:49:19',),
#  ('2:49:23',),
#  ('2:49:25',),
#  ('2:49:25',),
#  ('2:49:26',),
#  ('2:49:26',),
#  ('2:49:26',),
#  ('2:49:27',),
#  ('2:49:27',),
#  ('2:49:31',),
#  ('2:49:32',),
#  ('2:49:32',),
#  ('2:49:34',),
#  ('2:49:36',),
#  ('2:49:36',),
#  ('2:49:37',),
#  ('2:49:39',),
#  ('2:49:40',),
#  ('2:49:40',),
#  ('2:49:40',),
#  ('2:49:40',),
#  ('2:49:41',),
#  ('2:49:41',),
#  ('2:49:42',),
#  ('2:49:43',),
#  ('2:49:45',),
#  ('2:49:47',),
#  ('2:49:47',),
#  ('2:49:47',),
#  ('2:49:48',),
#  ('2:49:48',),
#  ('2:49:51',),
#  ('2:49:51',),
#  ('2:49:51',),
#  ('2:49:51',),
#  ('2:49:52',),
#  ('2:49:53',),
#  ('2:49:56',),
#  ('2:49:56',),
#  ('2:49:56',),
#  ('2:49:58',),
#  ('2:49:59',),
#  ('2:49:59',),
#  ('2:49:59',),
#  ('2:50:00',),
#  ('2:50:00',),
#  ('2:50:01',),
#  ('2:50:02',),
#  ('2:50:02',),
#  ('2:50:02',),
#  ('2:50:02',),
#  ('2:50:02',),
#  ('2:50:04',),
#  ('2:50:04',),
#  ('2:50:06',),
#  ('2:50:06',),
#  ('2:50:06',),
#  ('2:50:07',),
#  ('2:50:07',),
#  ('2:50:14',),
#  ('2:50:16',),
#  ('2:50:18',),
#  ('2:50:18',),
#  ('2:50:22',),
#  ('2:50:23',),
#  ('2:50:24',),
#  ('2:50:24',),
#  ('2:50:25',),
#  ('2:50:25',),
#  ('2:50:26',),
#  ('2:50:30',),
#  ('2:50:30',),
#  ('2:50:31',),
#  ('2:50:31',),
#  ('2:50:31',),
#  ('2:50:35',),
#  ('2:50:39',),
#  ('2:50:39',),
#  ('2:50:39',),
#  ('2:50:39',),
#  ('2:50:40',),
#  ('2:50:40',),
#  ('2:50:41',),
#  ('2:50:41',),
#  ('2:50:42',),
#  ('2:50:43',),
#  ('2:50:43',),
#  ('2:50:44',),
#  ('2:50:45',),
#  ('2:50:45',),
#  ('2:50:45',),
#  ('2:50:46',),
#  ('2:50:46',),
#  ('2:50:46',),
#  ('2:50:47',),
#  ('2:50:48',),
#  ('2:50:48',),
#  ('2:50:49',),
#  ('2:50:51',),
#  ('2:50:51',),
#  ('2:50:52',),
#  ('2:50:55',),
#  ('2:50:56',),
#  ('2:50:56',),
#  ('2:50:56',),
#  ('2:50:56',),
#  ('2:50:57',),
#  ('2:51:01',),
#  ('2:51:01',),
#  ('2:51:02',),
#  ('2:51:03',),
#  ('2:51:03',),
#  ('2:51:04',),
#  ('2:51:06',),
#  ('2:51:06',),
#  ('2:51:07',),
#  ('2:51:08',),
#  ('2:51:09',),
#  ('2:51:10',),
#  ('2:51:12',),
#  ('2:51:12',),
#  ('2:51:13',),
#  ('2:51:14',),
#  ('2:51:14',),
#  ('2:51:15',),
#  ('2:51:16',),
#  ('2:51:16',),
#  ('2:51:16',),
#  ('2:51:17',),
#  ('2:51:17',),
#  ('2:51:18',),
#  ('2:51:18',),
#  ('2:51:20',),
#  ('2:51:20',),
#  ('2:51:21',),
#  ('2:51:21',),
#  ('2:51:21',),
#  ('2:51:23',),
#  ('2:51:25',),
#  ('2:51:27',),
#  ('2:51:27',),
#  ('2:51:27',),
#  ('2:51:27',),
#  ('2:51:28',),
#  ('2:51:29',),
#  ('2:51:30',),
#  ('2:51:31',),
#  ('2:51:31',),
#  ('2:51:32',),
#  ('2:51:32',),
#  ('2:51:33',),
#  ('2:51:35',),
#  ('2:51:36',),
#  ('2:51:37',),
#  ('2:51:37',),
#  ('2:51:38',),
#  ('2:51:38',),
#  ('2:51:39',),
#  ('2:51:39',),
#  ('2:51:42',),
#  ('2:51:43',),
#  ('2:51:44',),
#  ('2:51:45',),
#  ('2:51:45',),
#  ('2:51:45',),
#  ('2:51:46',),
#  ('2:51:46',),
#  ('2:51:46',),
#  ('2:51:46',),
#  ('2:51:46',),
#  ('2:51:47',),
#  ('2:51:48',),
#  ('2:51:48',),
#  ('2:51:48',),
#  ('2:51:49',),
#  ('2:51:50',),
#  ('2:51:51',),
#  ('2:51:51',),
#  ('2:51:52',),
#  ('2:51:54',),
#  ('2:51:56',),
#  ('2:51:56',),
#  ('2:51:56',),
#  ('2:51:56',),
#  ('2:51:58',),
#  ('2:52:01',),
#  ('2:52:03',),
#  ('2:52:04',),
#  ('2:52:07',),
#  ('2:52:08',),
#  ('2:52:09',),
#  ('2:52:09',),
#  ('2:52:11',),
#  ('2:52:11',),
#  ('2:52:12',),
#  ('2:52:13',),
#  ('2:52:13',),
#  ('2:52:15',),
#  ('2:52:16',),
#  ('2:52:16',),
#  ('2:52:17',),
#  ('2:52:17',),
#  ('2:52:18',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:21',),
#  ('2:52:22',),
#  ('2:52:23',),
#  ('2:52:24',),
#  ('2:52:24',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:25',),
#  ('2:52:26',),
#  ('2:52:28',),
#  ('2:52:29',),
#  ('2:52:29',),
#  ('2:52:31',),
#  ('2:52:31',),
#  ('2:52:32',),
#  ('2:52:32',),
#  ('2:52:33',),
#  ('2:52:33',),
#  ('2:52:33',),
#  ('2:52:34',),
#  ('2:52:35',),
#  ('2:52:36',),
#  ('2:52:36',),
#  ('2:52:37',),
#  ('2:52:37',),
#  ('2:52:39',),
#  ('2:52:39',),
#  ('2:52:41',),
#  ('2:52:41',),
#  ('2:52:43',),
#  ('2:52:44',),
#  ('2:52:45',),
#  ('2:52:45',),
#  ('2:52:46',),
#  ('2:52:46',),
#  ('2:52:48',),
#  ('2:52:49',),
#  ('2:52:51',),
#  ('2:52:52',),
#  ('2:52:52',),
#  ('2:52:52',),
#  ('2:52:54',),
#  ('2:52:54',),
#  ('2:52:55',),
#  ('2:52:56',),
#  ('2:52:58',),
#  ('2:52:58',),
#  ('2:52:58',),
#  ('2:52:59',),
#  ('2:52:59',),
#  ('2:52:59',),
#  ('2:53:00',),
#  ('2:53:00',),
#  ('2:53:00',),
#  ('2:53:02',),
#  ('2:53:02',),
#  ('2:53:04',),
#  ('2:53:04',),
#  ('2:53:05',),
#  ('2:53:05',),
#  ('2:53:05',),
#  ('2:53:05',),
#  ('2:53:06',),
#  ('2:53:06',),
#  ('2:53:07',),
#  ('2:53:09',),
#  ('2:53:10',),
#  ('2:53:10',),
#  ('2:53:13',),
#  ('2:53:13',),
#  ('2:53:15',),
#  ('2:53:16',),
#  ('2:53:17',),
#  ('2:53:17',),
#  ('2:53:19',),
#  ('2:53:20',),
#  ('2:53:21',),
#  ('2:53:22',),
#  ('2:53:23',),
#  ('2:53:24',),
#  ('2:53:25',),
#  ('2:53:26',),
#  ('2:53:27',),
#  ('2:53:27',),
#  ('2:53:28',),
#  ('2:53:29',),
#  ('2:53:29',),
#  ('2:53:30',),
#  ('2:53:33',),
#  ('2:53:34',),
#  ('2:53:35',),
#  ('2:53:36',),
#  ('2:53:37',),
#  ('2:53:37',),
#  ('2:53:38',),
#  ('2:53:38',),
#  ('2:53:38',),
#  ('2:53:38',),
#  ('2:53:39',),
#  ('2:53:39',),
#  ('2:53:39',),
#  ('2:53:40',),
#  ('2:53:40',),
#  ('2:53:41',),
#  ('2:53:41',),
#  ('2:53:41',),
#  ('2:53:41',),
#  ('2:53:42',),
#  ('2:53:44',),
#  ('2:53:44',),
#  ('2:53:44',),
#  ('2:53:46',),
#  ('2:53:47',),
#  ('2:53:49',),
#  ('2:53:49',),
#  ('2:53:50',),
#  ('2:53:51',),
#  ('2:53:52',),
#  ('2:53:52',),
#  ('2:53:53',),
#  ('2:53:54',),
#  ('2:53:54',),
#  ('2:53:54',),
#  ('2:53:55',),
#  ('2:53:56',),
#  ('2:53:57',),
#  ('2:53:58',),
#  ('2:54:00',),
#  ('2:54:02',),
#  ('2:54:02',),
#  ('2:54:03',),
#  ('2:54:03',),
#  ('2:54:03',),
#  ('2:54:04',),
#  ('2:54:04',),
#  ('2:54:04',),
#  ('2:54:05',),
#  ('2:54:06',),
#  ('2:54:06',),
#  ('2:54:07',),
#  ('2:54:07',),
#  ('2:54:08',),
#  ('2:54:08',),
#  ('2:54:10',),
#  ('2:54:10',),
#  ('2:54:11',),
#  ('2:54:13',),
#  ('2:54:13',),
#  ('2:54:14',),
#  ('2:54:14',),
#  ('2:54:14',),
#  ('2:54:14',),
#  ('2:54:16',),
#  ('2:54:17',),
#  ('2:54:17',),
#  ('2:54:17',),
#  ('2:54:18',),
#  ('2:54:18',),
#  ('2:54:19',),
#  ('2:54:19',),
#  ('2:54:19',),
#  ('2:54:21',),
#  ('2:54:21',),
#  ('2:54:23',),
#  ('2:54:23',),
#  ('2:54:28',),
#  ('2:54:30',),
#  ('2:54:31',),
#  ('2:54:31',),
#  ('2:54:32',),
#  ('2:54:32',),
#  ('2:54:32',),
#  ('2:54:32',),
#  ('2:54:32',),
#  ('2:54:32',),
#  ('2:54:34',),
#  ('2:54:35',),
#  ('2:54:35',),
#  ('2:54:35',),
#  ('2:54:36',),
#  ('2:54:37',),
#  ('2:54:39',),
#  ('2:54:39',),
#  ('2:54:39',),
#  ('2:54:39',),
#  ('2:54:40',),
#  ('2:54:43',),
#  ('2:54:44',),
#  ('2:54:44',),
#  ('2:54:45',),
#  ('2:54:45',),
#  ('2:54:45',),
#  ('2:54:46',),
#  ('2:54:46',),
#  ('2:54:48',),
#  ('2:54:49',),
#  ('2:54:49',),
#  ('2:54:49',),
#  ('2:54:50',),
#  ('2:54:50',),
#  ('2:54:51',),
#  ('2:54:51',),
#  ('2:54:52',),
#  ('2:54:52',),
#  ('2:54:52',),
#  ('2:54:52',),
#  ('2:54:52',),
#  ('2:54:54',),
#  ('2:54:54',),
#  ('2:54:56',),
#  ('2:54:57',),
#  ('2:54:57',),
#  ('2:54:58',),
#  ('2:54:58',),
#  ('2:54:59',),
#  ('2:55:00',),
#  ('2:55:02',),
#  ('2:55:05',),
#  ('2:55:05',),
#  ('2:55:05',),
#  ('2:55:06',),
#  ('2:55:06',),
#  ('2:55:08',),
#  ('2:55:08',),
#  ('2:55:08',),
#  ('2:55:09',),
#  ('2:55:10',),
#  ('2:55:11',),
#  ('2:55:13',),
#  ('2:55:15',),
#  ('2:55:15',),
#  ('2:55:16',),
#  ('2:55:16',),
#  ('2:55:16',),
#  ('2:55:17',),
#  ('2:55:18',),
#  ('2:55:18',),
#  ('2:55:18',),
#  ('2:55:18',),
#  ('2:55:18',),
#  ('2:55:20',),
#  ('2:55:20',),
#  ('2:55:22',),
#  ('2:55:24',),
#  ('2:55:24',),
#  ('2:55:25',),
#  ('2:55:25',),
#  ('2:55:26',),
#  ('2:55:28',),
#  ('2:55:30',),
#  ('2:55:30',),
#  ('2:55:31',),
#  ('2:55:31',),
#  ('2:55:31',),
#  ('2:55:31',),
#  ('2:55:32',),
#  ('2:55:32',),
#  ('2:55:33',),
#  ('2:55:33',),
#  ('2:55:34',),
#  ('2:55:35',),
#  ('2:55:35',),
#  ('2:55:36',),
#  ('2:55:36',),
#  ('2:55:36',),
#  ('2:55:37',),
#  ('2:55:37',),
#  ('2:55:38',),
#  ('2:55:42',),
#  ('2:55:42',),
#  ('2:55:42',),
#  ('2:55:43',),
#  ('2:55:44',),
#  ('2:55:45',),
#  ('2:55:45',),
#  ('2:55:45',),
#  ('2:55:45',),
#  ('2:55:46',),
#  ('2:55:47',),
#  ('2:55:50',),
#  ('2:55:50',),
#  ('2:55:50',),
#  ('2:55:50',),
#  ('2:55:51',),
#  ('2:55:52',),
#  ('2:55:52',),
#  ('2:55:53',),
#  ('2:55:53',),
#  ('2:55:54',),
#  ('2:55:57',),
#  ('2:55:57',),
#  ('2:55:58',),
#  ('2:55:59',),
#  ('2:56:01',),
#  ('2:56:02',),
#  ('2:56:03',),
#  ('2:56:03',),
#  ('2:56:03',),
#  ('2:56:04',),
#  ('2:56:04',),
#  ('2:56:06',),
#  ('2:56:06',),
#  ('2:56:07',),
#  ('2:56:07',),
#  ('2:56:09',),
#  ('2:56:09',),
#  ('2:56:10',),
#  ('2:56:11',),
#  ('2:56:12',),
#  ('2:56:12',),
#  ('2:56:12',),
#  ('2:56:12',),
#  ('2:56:12',),
#  ('2:56:13',),
#  ('2:56:13',),
#  ('2:56:14',),
#  ('2:56:15',),
#  ('2:56:15',),
#  ('2:56:16',),
#  ('2:56:16',),
#  ('2:56:16',),
#  ('2:56:17',),
#  ('2:56:17',),
#  ('2:56:17',),
#  ('2:56:18',),
#  ('2:56:18',),
#  ('2:56:18',),
#  ('2:56:19',),
#  ('2:56:19',),
#  ('2:56:21',),
#  ('2:56:21',),
#  ('2:56:21',),
#  ('2:56:22',),
#  ('2:56:22',),
#  ('2:56:23',),
#  ('2:56:24',),
#  ('2:56:24',),
#  ('2:56:24',),
#  ('2:56:25',),
#  ('2:56:25',),
#  ('2:56:25',),
#  ('2:56:25',),
#  ('2:56:26',),
#  ('2:56:27',),
#  ('2:56:28',),
#  ...]

# %%
# Challenge 2
# Which countries came top 3 in completing the marathon before 2hrs 15min?
#

# %%sql
Select Name, Country, "Official Time" from MarathonResults
Where "Official Time"<'02:15:00' 
Order by "Official Time" ;
# Out:
#  * sqlite://
# Done.
# [('Hayle, Lemi Berhanu', 'ETH', '02:12:45'),
#  ('Desisa, Lelisa', 'ETH', '02:13:32'),
#  ('Tsegay, Yemane Adhane', 'ETH', '02:14:02'),
#  ('Korir, Wesley', 'KEN', '02:14:05')]

# %%
# Challenge 3
# How many athletes ran 30K under 1hr 34min? Name these athletes.
# 

# %%sql
Select Name, Country, "30K","Official Time" Overall from MarathonResults
Where "30K" < '1:34:00' and "30K" > 0
Order by "30K";
# Out:
#  * sqlite://
# Done.
# []

# %% [markdown]
# ## 1.4 Date Strings

# %%
# Example 1
# At times we would like to work with the data that is stored in the form of dates
# However, this kind of data can be really difficult to work with if it is not stored
# in datetime Data Type i.e. YYYY-MM-DD HH:MM:SS. It can even be misleading while 
# performing operations to our data. 
# Thus, when we get a dataset such as the one previewed below we will note that the datetime data 
# within the "Date_End_of_Quater" column is not in the datetime Data Type. 
# We will need to fix this;
# 
# %sql SELECT * FROM VisitorsKenya LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [('Arrivals', '03/31/2005 12:00:00 AM', '2005', 264600, 'Visitors on Holiday', 'Q1', 'Actual', 0),
#  ('Arrivals', '06/30/1991 12:00:00 AM', '1991', 149400, 'Visitors on Holiday', 'Q2', 'Actual', 1),
#  ('Arrivals', '09/30/1991 12:00:00 AM', '1991', 215900, 'Visitors on Holiday', 'Q3', 'Actual', 2),
#  ('Arrivals', '12/31/1991 12:00:00 AM', '1991', 158400, 'Visitors on Holiday', 'Q4', 'Actual', 3),
#  ('Arrivals', '03/31/1992 12:00:00 AM', '1992', 155400, 'Visitors on Holiday', 'Q1', 'Actual', 4)]

# %%
# Example 2
# In order to convert this kind of data to this format YYYY-MM-DD HH:MM:SS, 
# we would need to use the substring function. 
# An example of how the SQL substring function works is as shown in the SQL command
# in this cell;
# NB: Run this cell several times as you make changes to the numerical parameters 1, 6 
# and then observe the output after running this cell
#
# %%sql
SELECT substr('SQL Tutorial', 1, 6) AS ExtractString;
# Out:
#  * sqlite://
# Done.
# [('SQL Tu',)]

# %%
# Example 3
# Let's now select the "Date_End_of_Quater" data in the datetime data type format.
# We will apply the SQL substr function to the respective column
# then select the characters specifying our range then concatenating (combining)
# the selected substrings.
#  
# %%sql
SELECT substr("Date_End_of_Quater", 7, 4) 
|| "-" || substr("Date_End_of_Quater", 4, 2) 
|| "-" || substr("Date_End_of_Quater", 1, 2) 
|| " " || substr("Date_End_of_Quater", 12,9)
AS New_Date_End_of_Quarter
FROM VisitorsKenya Limit 5;
# Out:
#  * sqlite://
# Done.
# [('2005-31-03 12:00:00 ',),
#  ('1991-30-06 12:00:00 ',),
#  ('1991-30-09 12:00:00 ',),
#  ('1991-31-12 12:00:00 ',),
#  ('1992-31-03 12:00:00 ',)]

# %%
# Example 4
# Once we are certain that the selected data is in the datetime data type format,
# we can then update the table as shown; Remember we learnt how to update data 
# in our table last week? :) 
# This will allow us to start using that updated table for further investigation
# 
# %%sql
UPDATE VisitorsKenya 
set "Date_End_of_Quater" = substr("Date_End_of_Quater", 7, 4) 
|| "-" || substr("Date_End_of_Quater", 4, 2) 
|| "-" || substr("Date_End_of_Quater", 1, 2) 
|| " " || substr("Date_End_of_Quater", 12,9)
# Out:
#  * sqlite://
# 832 rows affected.
# []

# %%
# Example 5
# We can preview our dataset below so as to note the changes we have made to our 
# "Date_End_of_Quater" column which now looks super :) 
# 
# %%sql
SELECT * 
FROM VisitorsKenya Limit 5;
# Out:
#  * sqlite://
# Done.
# [('Arrivals', '2005-31-03 12:00:00 ', '2005', 264600, 'Visitors on Holiday', 'Q1', 'Actual', 0),
#  ('Arrivals', '1991-30-06 12:00:00 ', '1991', 149400, 'Visitors on Holiday', 'Q2', 'Actual', 1),
#  ('Arrivals', '1991-30-09 12:00:00 ', '1991', 215900, 'Visitors on Holiday', 'Q3', 'Actual', 2),
#  ('Arrivals', '1991-31-12 12:00:00 ', '1991', 158400, 'Visitors on Holiday', 'Q4', 'Actual', 3),
#  ('Arrivals', '1992-31-03 12:00:00 ', '1992', 155400, 'Visitors on Holiday', 'Q1', 'Actual', 4)]

# %%
# Example 6
# We now continue into investigating our dataset; We answer the following question;
# Which arrivals and depatures happened before 10th June, 1991?  
# Solution:
#
# %%sql
SELECT * 
FROM VisitorsKenya 
WHERE "Date_End_of_Quater" < '1991-30-10';
# Out:
#  * sqlite://
# Done.
# [('Arrivals', '1991-30-06 12:00:00 ', '1991', 149400, 'Visitors on Holiday', 'Q2', 'Actual', 1),
#  ('Arrivals', '1991-30-09 12:00:00 ', '1991', 215900, 'Visitors on Holiday', 'Q3', 'Actual', 2),
#  ('Departures', '1991-30-06 12:00:00 ', '1991', 111200, 'Visitors on Holiday', 'Q2', 'Actual', 148),
#  ('Departures', '1991-30-09 12:00:00 ', '1991', 156200, 'Visitors on Holiday', 'Q3', 'Actual', 168),
#  ('Arrivals', '1991-30-06 12:00:00 ', '1991', 16600, 'Visitors on Business', 'Q2', 'Actual', 209),
#  ('Arrivals', '1991-30-09 12:00:00 ', '1991', 23100, 'Visitors on Business', 'Q3', 'Actual', 210),
#  ('Departures', '1991-30-06 12:00:00 ', '1991', 17900, 'Visitors on Business', 'Q2', 'Actual', 356),
#  ('Departures', '1991-30-09 12:00:00 ', '1991', 17800, 'Visitors on Business', 'Q3', 'Actual', 376),
#  ('Arrivals', '1991-30-06 12:00:00 ', '1991', 5100, 'Visitors in Transit', 'Q2', 'Actual', 417),
#  ('Arrivals', '1991-30-09 12:00:00 ', '1991', 13200, 'Visitors in Transit', 'Q3', 'Actual', 418),
#  ('Departures', '1991-30-06 12:00:00 ', '1991', 11100, 'Visitors in Transit', 'Q2', 'Actual', 564),
#  ('Departures', '1991-30-09 12:00:00 ', '1991', 11700, 'Visitors in Transit', 'Q3', 'Actual', 584),
#  ('Arrivals', '1991-30-06 12:00:00 ', '1991', 2400, 'Other', 'Q2', 'Actual', 625),
#  ('Arrivals', '1991-30-09 12:00:00 ', '1991', 4100, 'Other', 'Q3', 'Actual', 626),
#  ('Departures', '1991-30-06 12:00:00 ', '1991', 1200, 'Other', 'Q2', 'Actual', 772),
#  ('Departures', '1991-30-09 12:00:00 ', '1991', 2200, 'Other', 'Q3', 'Actual', 792)]

# %%
# Example 7
# Which arrivals and depatures happened after 30th June 2000?  
#
# %%sql
SELECT * 
FROM VisitorsKenya 
WHERE "Date_End_of_Quater" > '2000-30-06' Limit 5;
# Out:
#  * sqlite://
# Done.
# [('Arrivals', '2005-31-03 12:00:00 ', '2005', 264600, 'Visitors on Holiday', 'Q1', 'Actual', 0),
#  ('Arrivals', '2000-31-03 12:00:00 ', '2000', 194500, 'Visitors on Holiday', 'Q1', 'Actual', 36),
#  ('Arrivals', '2000-30-06 12:00:00 ', '2000', 165500, 'Visitors on Holiday', 'Q2', 'Actual', 37),
#  ('Arrivals', '2000-30-09 12:00:00 ', '2000', 211100, 'Visitors on Holiday', 'Q3', 'Actual', 38),
#  ('Arrivals', '2000-31-12 12:00:00 ', '2000', 207100, 'Visitors on Holiday', 'Q4', 'Actual', 39)]

# %% [markdown]
# ### <font color="green">1.4 Challenges</font>

# %%
# Challenge
# Using the tea_production dataset, which three dates had tea production 
# before the date with the most tea production?
#

# %%sql
SELECT substr("Date", 7, 4) 
|| "-" || substr("Date", 4, 2) 
|| "-" || substr("Date", 1, 2) 
|| " " || substr("Date", 12,9)
AS New_Date
FROM TeaProduction Limit 5;
# Out:
#  * sqlite://
# Done.
# [('2003-25-01 12:00:00 ',),
#  ('2003-25-02 12:00:00 ',),
#  ('2003-25-03 12:00:00 ',),
#  ('2003-25-04 12:00:00 ',),
#  ('2003-25-05 12:00:00 ',)]

# %%
# %%sql
# UPDATE TeaProduction
# set "Date" = substr("Date", 7, 4)
# || "-" || substr("Date", 4, 2)
# || "-" || substr("Date", 1, 2)
# || " " || substr("Date", 12,9)
# Out:
#  * sqlite://
# 407 rows affected.
# []

# %%
# %%sql
# Select Date, Max("Millions_in_KGS") from TeaProduction
# Out:
#  * sqlite://
# Done.
# [('2003-25-01 12:00:00 ', 'Millions_in_KGS')]

# %%
# %%sql
# Select * from TeaProduction
# Where Activity_in_Tea_Sector = 'Production' and Date < '2003-25-01' Order by Date limit 3;
# Out:
#  * sqlite://
# Done.
# []
